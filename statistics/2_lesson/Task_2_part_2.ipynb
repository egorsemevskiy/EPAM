# %% [markdown]
# # Part 2
#
# Using 𝐶ℎ𝑖2 criteria check whether there is a statistical difference between men's and women's choice of auto. (Features Sex и PreferCar)

# %%
import pandas as pd
import numpy as np

from scipy.stats import chi2_contingency
from scipy.stats import chi2
import researchpy as rp

# %%
df = pd.read_csv('data/raw/HW1_task2_car_prefs_data.tsv' ,sep='\t')

# %% [markdown]
# Смотрим датасет

# %%
df.head()
# Out:
#     ID  Age  Sex  LicYr  LicMth  ActCar  Kids5  Kids6  PreferCar  Car15K  ...  \
# 0  110   18    2      0       2       3      2      2          2       2  ...
# 1  111   25    1      8       0       1      2      2          1       1  ...
# 2  112   63    2     46       0       3      2      2          3       2  ...
# 3  113   51    1     35       0       3      2      2          2       2  ...
# 4  114   19    1      2       0       2      2      2          2       1  ...
#
#    Reliable  Perform  Fuel  Safety  AC/PS  Park  Room  Doors  Prestige  Colour
# 0         4        3     3       3      3     3     3      3         3       2
# 1         4        4     4       4      3     4     4      2         3       3
# 2         3        3     3       3      3     3     3      3         3       3
# 3         3        3     3       4      3     3     3      3         1       3
# 4         3        4     3       3      2     3     3      2         3       3
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#                ID         Age         Sex       LicYr      LicMth      ActCar  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean   209.986667   34.123333    1.500000   15.240000    0.620000    2.000000
# std    108.131562   15.344695    0.500835   14.424376    1.995547    0.817861
# min      1.000000   18.000000    1.000000    0.000000    0.000000    1.000000
# 25%    117.750000   21.000000    1.000000    3.000000    0.000000    1.000000
# 50%    206.500000   27.000000    1.500000    9.000000    0.000000    2.000000
# 75%    307.250000   46.000000    2.000000   26.000000    0.000000    3.000000
# max    393.000000   75.000000    2.000000   57.000000   11.000000    3.000000
#
#             Kids5       Kids6  PreferCar      Car15K  ...    Reliable  \
# count  300.000000  300.000000  300.00000  300.000000  ...  300.000000
# mean     1.903333    1.736667    2.17000    1.536667  ...    3.830000
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df_chi = df[['Sex','PreferCar']]

# %% [markdown]
# Как видим, пропущенных значений нет, можно делать статистику

# %% [markdown]
# In this test we will check is there any relationship between Sex and PreferCar

# %% [markdown]
# ## Define Hypothesis

# %% [markdown]
# Null Hypothesis (H0): Two variables are independent.
#
# Alternate Hypothesis (H1): Two variables are not independent.

# %% [markdown]
# ## chi^2 test

# %%
crosstab, test_results, expected  = rp.crosstab(df_chi["Sex"], df_chi["PreferCar"],
                                                test= "chi-square",
                                                expected_freqs= True,
                                                prop= "cell")

crosstab
# Out:
#           PreferCar
# PreferCar         1      2      3     4    All
# Sex
# 1             14.33  25.00   8.67  2.00   50.0
# 2              8.33  20.33  15.67  5.67   50.0
# All           22.67  45.33  24.33  7.67  100.0

# %%
test_results
# Out:
#                 Chi-square test  results
# 0  Pearson Chi-square ( 3.0) =   17.5078
# 1                    p-value =    0.0006
# 2                 Cramer's V =    0.2416

# %% [markdown]
# Как мы видим, у нас есть основания отвергнуть нулевую гипотезу, что две переменные независимы
#
# И по таблице Крамера получаем сильную, и близку к очень сильной, корреляцию
